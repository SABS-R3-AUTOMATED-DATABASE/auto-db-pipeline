# %% [markdown]
# ## Auto-AbDab
#
# **Pipeline for the automatic generation of disease-specific antibody databases**

# %%
from auto_abdab import (
    utils,
    patents_pipeline, 
    get_supp_seqs,
    keywords2papers,
    keywords2pdbs,
    genbank_pipeline,
    collate_results
    )
# Out:
# WARNING:paperscraper.load_dumps: No dump found for biorxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dump found for chemrxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dump found for medrxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dumps found for either biorxiv or medrxiv. Consider using paperscraper.get_dumps.* to fetch the dumps.

# %% [markdown]
# 1. load keywords and known antigens from test file

# %%
keywords_disease = utils.load_keywords('../src/covid_keywords.txt')
known_antigens = utils.load_known_antigens('../src/covid_known_antigens.txt')

# %%
keywords_disease
# Out:
# ['COVID-19',
#  'CORONAVIRUS',
#  'SARS-COV',
#  'MERS-COV',
#  'SARS',
#  'SARS-COV-2',
#  'SPIKE PROTEIN',
#  'RBD',
#  'RECEPTOR-BINDING DOMAIN',
#  'MERS',
#  'MIDDLE EAST RESPIRATORY SYNDROME',
#  'SEVERE ACUTE RESPIRATORY SYNDROME']

# %%
known_antigens
# Out:
# {'COVID': ['coronavirus', 'sars-cov', 'sars'],
#  'MERS': ['mers-cov', 'mers'],
#  'SARS-COV-2': ['sars-cov-2', 'covid-19'],
#  'SARS-COV-1': ['sars-cov-1'],
#  'Spike protein': ['spike', 'spike protein'],
#  'RBD': ['receptor binding domain', 'rbd']}

# %% [markdown]
# 2. search patents

# %%
patents_pipeline.get_seq_from_patents(keywords_disease)

# %% [markdown]
# 3. Search SI

# %%
# find paper links
k2p = keywords2papers.Keywords2Papers(keywords_disease)
pubmed_results = k2p.get_pubmed()
biorxiv_results = k2p.get_biorxiv()
paper_urls = papers2urls(pubmed_results, biorxiv_results)

# get sequences from supplementary material
get_seqs_from_supp(paper_urls)
# Out:
# getting pubmed
# fetching pubmed
# ((COVID-19) OR (CORONAVIRUS) OR (SARS-COV) OR (MERS-COV) OR (SARS) OR (SARS-COV-2) OR (SPIKE PROTEIN) OR (RBD) OR (RECEPTOR-BINDING DOMAIN) OR (MERS) OR (MIDDLE EAST RESPIRATORY SYNDROME) OR (SEVERE ACUTE RESPIRATORY SYNDROME)) AND ((antibody) OR (antibodies) OR (nanobody) OR (immunoglobulin) OR (MAb) OR (nanobodies)) AND ((neutralizing) OR (neutralize) OR (neutralization) OR (bind) OR (binding) OR (inhibit) OR (targeting)) AND ((heavy chain) OR (complementarity determining region) OR (gene) OR (epitope) OR (receptor-binding domain) OR (rbd) OR (spike protein) OR (VHH))
# ['title', 'authors', 'date', 'abstract', 'journal', 'doi']
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus.stats.ox.ac.uk/homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # find paper links
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus.stats.ox.ac.uk/homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> k2p = keywords2papers.Keywords2Papers(keywords_disease)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpegasus.stats.ox.ac.uk/homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> pubmed_results = k2p.get_pubmed()
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus.stats.ox.ac.uk/homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> biorxiv_results = k2p.get_biorxiv()
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus.stats.ox.ac.uk/homes/spoendli/Projects/auto-db-pipeline/notebooks/example_run.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> paper_urls = papers2urls(pubmed_results, biorxiv_results)
#
# File ~/Projects/auto-db-pipeline/auto_abdab/parse_supp/keywords2papers.py:75, in Keywords2Papers.get_pubmed(self)
#      72     self.pubmed_results = self.load_output(FILENAME_PUBMED)
#      73     return self.pubmed_results
# ---> 75 self.pubmed_results = Keywords2Papers.fetch_pubmed(keywords=self.KEYWORDS)
#      76 self.store_output(self.pubmed_results, FILENAME_PUBMED)
#      77 return self.pubmed_results
#
# File ~/Projects/auto-db-pipeline/auto_abdab/parse_supp/keywords2papers.py:217, in Keywords2Papers.fetch_pubmed(keywords, fields, start_date, end_date)
#     208 """
#     209 Search for papers and preprints on PubMed
#     210 Returns:
#    (...)
#     213     AND/OR files containing relevant information
#     214 """
#     215 print('fetching pubmed')
# --> 217 papers_output = Keywords2Papers._query_pubmed(keywords, fields, start_date, end_date)
#     218 papers_pt_output = Keywords2Papers._query_pubmed(keywords+['AND preprint[pt]'],
#     219                                                 fields, start_date, end_date)
#     220 output = papers_output + papers_pt_output
#
# File ~/Projects/auto-db-pipeline/auto_abdab/parse_supp/keywords2papers.py:263, in Keywords2Papers._query_pubmed(keywords, fields, start_date, end_date)
#     261 print(query)
#     262 print(fields)
# --> 263 output = get_pubmed_papers(query, fields)
#     264 output = [{field: entry.get(field, None) for field in fields} for entry in output]
#     265 return output
#
# File /data/localhost/not-backed-up/spoendli/miniconda3/envs/auto_abdab/lib/python3.10/site-packages/paperscraper/pubmed/pubmed.py:51, in get_pubmed_papers(query, fields, max_results, *args, **kwargs)
#      28 def get_pubmed_papers(
#      29     query: str,
#      30     fields: List = ["title", "authors", "date", "abstract", "journal", "doi"],
#    (...)
#      33     **kwargs
#      34 ) -> pd.DataFrame:
#      35     """
#      36     Performs PubMed API request of a query and returns list of papers with
#      37     fields as desired.
#    (...)
#      49
#      50     """
# ---> 51     raw = list(PUBMED.query(query, max_results=max_results, *args, **kwargs))
#      53     get_mails = "emails" in fields
#      54     if get_mails:
#
# File /data/localhost/not-backed-up/spoendli/miniconda3/envs/auto_abdab/lib/python3.10/site-packages/pymed/api.py:62, in PubMed.query(self, query, max_results)
#      50 """ Method that executes a query agains the GraphQL schema, automatically
#      51     inserting the PubMed data loader.
#      52
#    (...)
#      58                     in the "data" attribute.
#      59 """
#      61 # Retrieve the article IDs for the query
# ---> 62 article_ids = self._getArticleIds(query=query, max_results=max_results)
#      64 # Get the articles themselves
#      65 articles = list(
#      66     [
#      67         self._getArticles(article_ids=batch)
#      68         for batch in batches(article_ids, 250)
#      69     ]
#      70 )
#
# File /data/localhost/not-backed-up/spoendli/miniconda3/envs/auto_abdab/lib/python3.10/site-packages/pymed/api.py:208, in PubMed._getArticleIds(self, query, max_results)
#     205     parameters["retmax"] = max_results
#     207 # Make the first request to PubMed
# --> 208 response = self._get(url="/entrez/eutils/esearch.fcgi", parameters=parameters)
#     210 # Add the retrieved IDs to the list
#     211 article_ids += response.get("esearchresult", {}).get("idlist", [])
#
# File /data/localhost/not-backed-up/spoendli/miniconda3/envs/auto_abdab/lib/python3.10/site-packages/pymed/api.py:143, in PubMed._get(self, url, parameters, output)
#     140 response = requests.get(f"{BASE_URL}{url}", params=parameters)
#     142 # Check for any errors
# --> 143 response.raise_for_status()
#     145 # Add this request to the list of requests made
#     146 self._requestsMade.append(datetime.datetime.now())
#
# File /data/localhost/not-backed-up/spoendli/miniconda3/envs/auto_abdab/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?tool=MyTool&email=abc%40def.gh&db=pubmed&term=%28%28COVID-19%29+OR+%28CORONAVIRUS%29+OR+%28SARS-COV%29+OR+%28MERS-COV%29+OR+%28SARS%29+OR+%28SARS-COV-2%29+OR+%28SPIKE+PROTEIN%29+OR+%28RBD%29+OR+%28RECEPTOR-BINDING+DOMAIN%29+OR+%28MERS%29+OR+%28MIDDLE+EAST+RESPIRATORY+SYNDROME%29+OR+%28SEVERE+ACUTE+RESPIRATORY+SYNDROME%29%29+AND+%28%28antibody%29+OR+%28antibodies%29+OR+%28nanobody%29+OR+%28immunoglobulin%29+OR+%28MAb%29+OR+%28nanobodies%29%29+AND+%28%28neutralizing%29+OR+%28neutralize%29+OR+%28neutralization%29+OR+%28bind%29+OR+%28binding%29+OR+%28inhibit%29+OR+%28targeting%29%29+AND+%28%28heavy+chain%29+OR+%28complementarity+determining+region%29+OR+%28gene%29+OR+%28epitope%29+OR+%28receptor-binding+domain%29+OR+%28rbd%29+OR+%28spike+protein%29+OR+%28VHH%29%29&retmax=50000&retmode=json

# %% [markdown]
# 4. Search PDB

# %%
keywords2pdbs.get_or_update_pdb_chains(keywords_disease, save=True)

# %% [markdown]
# 5. search genbank

# %%
genbank_pipeline.get_seqs_from_genbank(keywords_disease, known_antigens, output_path='../data/genbank/')

# %% [markdown]
# 6. Create database

# %%
collate_results.collate_results(outfile_name='../data/final_antibody_db.csv')
# Out:
# Running dataframes through IgBLAST and ANARCI...
# PATENT
# Limiting hmmer search to species ['human', 'mouse'] was requested but hits did not achieve a high enough bitscore. Reverting to using any species
# Limiting hmmer search to species ['human', 'mouse'] was requested but hits did not achieve a high enough bitscore. Reverting to using any species
# Total number of sequences input:  4764
# Total sequences N/A from input:  239
# Total sequences lost after failing ANARCI filtering:  184
# SI
# Total number of sequences input:  916
# Total sequences N/A from input:  1
# Total sequences lost after failing ANARCI filtering:  0
# PDB
# Limiting hmmer search to species ['human', 'mouse'] was requested but hits did not achieve a high enough bitscore. Reverting to using any species
# Limiting hmmer search to species ['human', 'mouse'] was requested but hits did not achieve a high enough bitscore. Reverting to using any species
# Total number of sequences input:  1706
# Total sequences N/A from input:  0
# Total sequences lost after failing ANARCI filtering:  213
# GENBANK
# genbank paired
# Total number of sequences input:  1264
# Total sequences N/A from input:  143
# Total sequences lost after failing ANARCI filtering:  0
# genbank unpaired
# Total number of sequences input:  12430
# Total sequences N/A from input:  6223
# Total sequences lost after failing ANARCI filtering:  0
# Adding webscraping source to database...
# Creating final database...
# Database created.
# --- 717 seconds ---
#      Scrape source                                                URL  \
# 0           Patent  https://patents.google.com/patent/US11034762B1/en
# 1           Patent  https://patents.google.com/patent/US11034762B1/en
# 2           Patent  https://patents.google.com/patent/US11034762B1/en
# 3           Patent  https://patents.google.com/patent/US11034762B1/en
# 4           Patent  https://patents.google.com/patent/US11034762B1/en
# ...            ...                                                ...
# 6210       GenBank                                                NaN
# 6211       GenBank                                                NaN
# 6212       GenBank                                                NaN
# 6213       GenBank                                                NaN
# 6214       GenBank                                                NaN
#
#                                                  Source  \
# 0     (334/394) in one instance, the antibody or ant...
# 1     (318/378) in one instance, the antibody or ant...
# 2     (322/382) in one instance, the antibody or ant...
# 3     (351/411) in one instance, the antibody or ant...
# 4     (323/383) in one instance, the antibody or ant...
# ...                                                 ...
# 6210                                                NaN
# 6211                                                NaN
# 6212                                                NaN
# 6213                                                NaN
# 6214                                                NaN
#
#                                               Reference  DOI PDB ID  \
# 0                                                   NaN  NaN    NaN
# 1                                                   NaN  NaN    NaN
# 2                                                   NaN  NaN    NaN
# 3                                                   NaN  NaN    NaN
# 4                                                   NaN  NaN    NaN
# ...                                                 ...  ...    ...
# 6210  Hong,J. et al.; Generation and characterizatio...  N/A    NaN
# 6211  Hong,J. et al.; Generation and characterizatio...  N/A    NaN
# 6212  Hong,J. et al.; Generation and characterizatio...  N/A    NaN
# 6213  Hong,J. et al.; Generation and characterizatio...  N/A    NaN
# 6214  Kang,X. et al.; Human neutralizing SARS-CoV sp...  N/A    NaN
#
#      GenBank ID VH GenBank ID VL                        Binds to  \
# 0              NaN           NaN                             NaN
# 1              NaN           NaN                             NaN
# 2              NaN           NaN                             NaN
# 3              NaN           NaN                             NaN
# 4              NaN           NaN                             NaN
# ...            ...           ...                             ...
# 6210           N/A      QIQ28233  ['COVID', 'SARS-COV-2', 'RBD']
# 6211           N/A      QIQ28232  ['COVID', 'SARS-COV-2', 'RBD']
# 6212           N/A      QIQ28231  ['COVID', 'SARS-COV-2', 'RBD']
# 6213           N/A      QIQ28230  ['COVID', 'SARS-COV-2', 'RBD']
# 6214           N/A      ABG79005                       ['COVID']
#
#                               Origin  ...     CDRH1     CDRH2         CDRH3  \
# 0                                NaN  ...  GGTFSSYA  INPGGGNT  AGEWGISTPMDV
# 1                                NaN  ...  GGTFSSYA  IYPGDSTT  YSGSGISTPMDV
# 2                                NaN  ...  GYTFTGHY  IYPGDSEA  AGGSGISTPMDV
# 3                                NaN  ...  GYGFITYW  IYPGDSET  AGGSGLFTPMDV
# 4                                NaN  ...  GGTFSSYA  IIPIFGTT  AGEWGISTPMDV
# ...                              ...  ...       ...       ...           ...
# 6210  Oryctolagus cuniculus (rabbit)  ...       NaN       NaN           NaN
# 6211  Oryctolagus cuniculus (rabbit)  ...       NaN       NaN           NaN
# 6212  Oryctolagus cuniculus (rabbit)  ...       NaN       NaN           NaN
# 6213  Oryctolagus cuniculus (rabbit)  ...       NaN       NaN           NaN
# 6214            Homo sapiens (human)  ...       NaN       NaN           NaN
#
#              CDRL1 CDRL2           CDRL3      Heavy J gene  \
# 0     QSVLYSSINKNY   WAS       QQYYGFPLT  IGHJ6*01 (human)
# 1     QSVLYSSINKNY   WAS       RQYYSTPWT  IGHJ6*01 (human)
# 2     QSVLYTSNNNNY   WGS       RQYYSTPWT  IGHJ6*01 (human)
# 3     QSVLYSSINKNY   WAS       QQYSTTPYT  IGHJ6*01 (human)
# 4     QSVLYSSINKNY   WAN       QQYYSTPLT  IGHJ6*01 (human)
# ...            ...   ...             ...               ...
# 6210        qsigtr   yas  lgehsyssgdgrta               NaN
# 6211        ediysn   das      qtyystvtra               NaN
# 6212        eniysf   tas    qqtdtysnvdna               NaN
# 6213      qsvydnnw   sas      aggysgnifa               NaN
# 6214        qnigtw   das     qqrlqwatent               NaN
#
#              Heavy V gene      Light J gene         Light V gene
# 0     IGHV1-69*01 (human)  IGKJ4*01 (human)   IGKV4-1*01 (human)
# 1     IGHV1-69*01 (human)  IGKJ4*01 (human)   IGKV4-1*01 (human)
# 2     IGHV1-46*01 (human)  IGKJ4*01 (human)   IGKV4-1*01 (human)
# 3     IGHV1-69*01 (human)  IGKJ4*01 (human)   IGKV4-1*01 (human)
# 4     IGHV1-69*01 (human)  IGKJ4*01 (human)   IGKV4-1*01 (human)
# ...                   ...               ...                  ...
# 6210                  NaN  IGKJ4*01 (human)   IGKV1-5*01 (human)
# 6211                  NaN  IGKJ4*01 (human)   IGKV1-5*01 (human)
# 6212                  NaN  IGKJ4*01 (human)  IGKV1-13*02 (human)
# 6213                  NaN  IGKJ5*01 (human)  IGKV1-12*01 (human)
# 6214                  NaN  IGKJ5*01 (human)  IGKV3-11*01 (human)
#
# [10540 rows x 25 columns]
